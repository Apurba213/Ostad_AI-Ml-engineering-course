# %% [markdown]
# <a href="https://colab.research.google.com/github/Apurba213/Ostad_AI-Ml-engineering-course/blob/main/Module7_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Datasets/heart.csv")

# %%
#Question 1: Dataset Loading and Initial Exploration
"""
1.Display the first five rows of the dataset
2.Display the last five rows of the dataset
3.Print the shape of the dataset"""
df.head()
df.tail()
df.shape

# %%
#Question 2: Dataset Structure and Missing Value Analysis
"""
1.Display all column names
2.Show dataset information including data types and non-null counts
3.Identify missing values in each column"""
df.columns
df.info()
df.isnull().sum()

# %%
#Question 3: Categorical Data Analysis
"""
Using appropriate Pandas methods:
1.Count the number of patients with heart disease (target = 1) and without heart disease (target = 0)
2.Count the number of male (sex = 1) and female (sex = 0) patients"""
df["target"].value_counts()
df["sex"].value_counts()

# %%
#Question 4: Data Selection Using iloc
"""
Perform the following operations using iloc only:
1.Select the first 10 rows of the dataset
2.Extract the columns representing age, sex, and cholesterol
3.Select rows from index 20 to 30 and columns from index 0 to 4"""
df.iloc[:10]
df.iloc[:,[0,1,4]]
df.iloc[20:31,0:5]

# %%
from numpy._core.defchararray import count
#Question 5: Data Filtering Using Conditions
"""
Apply conditional filtering to:

1.Extract all patients older than 50 years

2.Extract patients who have heart disease and a cholesterol level greater than 240

3.Count how many patients satisfy both conditions """
df[df["age"] > 50]
count=df[(df["target"]==1) & (df["chol"] > 240)]
count.shape[0]
# Out:
# 503
